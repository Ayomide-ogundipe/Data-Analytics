# %%
import numpy as np
import pandas as pd

# %%
bike_sharing = pd.read_csv('day.csv')
bike_sharing
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
bike_sharing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
#Year 2011 Data Set
bike_rental_11 = bike_sharing[bike_sharing['yr']==0]
bike_rental_11
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 360      361  2011-12-27       1   0    12        0        2           1
# 361      362  2011-12-28       1   0    12        0        3           1
# 362      363  2011-12-29       1   0    12        0        4           1
# 363      364  2011-12-30       1   0    12        0        5           1
# 364      365  2011-12-31       1   0    12        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#spring season
spring_rents = bike_rental_11[bike_rental_11['season']==1]
spring_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 360      361  2011-12-27       1   0    12        0        2           1
# 361      362  2011-12-28       1   0    12        0        3           1
# 362      363  2011-12-29       1   0    12        0        4           1
# 363      364  2011-12-30       1   0    12        0        5           1
# 364      365  2011-12-31       1   0    12        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#Total number of rental for spring in the year 2011
spring_rents['cnt'].sum()
# Out:
# 150000

# %%
#spring season 11 & 12
spring_rents = bike_sharing[bike_sharing['season']==1]
spring_rents['cnt'].max()

#Alternate & faster way for finding the maximum users per season instead of boolean indexing
#bike_sharing.groupby('season').max()['cnt']
# Out:
# 7836

# %%
spring_rents['casual'].sum()
# Out:
# 21425

# %%
spring_rents['registered'].sum()
# Out:
# 128575

# %%
#summer season
summer_rents = bike_rental_11[bike_rental_11['season']==2]
summer_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 79        80  2011-03-21       2   0     3        0        1           1
# 80        81  2011-03-22       2   0     3        0        2           1
# 81        82  2011-03-23       2   0     3        0        3           1
# 82        83  2011-03-24       2   0     3        0        4           1
# 83        84  2011-03-25       2   0     3        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 166      167  2011-06-16       2   0     6        0        4           1
# 167      168  2011-06-17       2   0     6        0        5           1
# 168      169  2011-06-18       2   0     6        0        6           0
# 169      170  2011-06-19       2   0     6        0        0           0
# 170      171  2011-06-20       2   0     6        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#Total number of rental for summer in the year 2011
summer_rents['cnt'].sum()
# Out:
# 347316

# %%
summer_rents['casual'].sum()
# Out:
# 77564

# %%
summer_rents['registered'].sum()
# Out:
# 269752

# %%
#fall season
fall_rents = bike_rental_11[bike_rental_11['season']==3]
fall_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 171      172  2011-06-21       3   0     6        0        2           1
# 172      173  2011-06-22       3   0     6        0        3           1
# 173      174  2011-06-23       3   0     6        0        4           1
# 174      175  2011-06-24       3   0     6        0        5           1
# 175      176  2011-06-25       3   0     6        0        6           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 260      261  2011-09-18       3   0     9        0        0           0
# 261      262  2011-09-19       3   0     9        0        1           1
# 262      263  2011-09-20       3   0     9        0        2           1
# 263      264  2011-09-21       3   0     9        0        3           1
# 264      265  2011-09-22       3   0     9        0        4           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#Total number of rental for fall in the year 2011
fall_rents['cnt'].sum()
# Out:
# 419650

# %%
fall_rents['casual'].sum()
# Out:
# 95450

# %%
fall_rents['registered'].sum()
# Out:
# 324200

# %%
#winter season
winter_rents = bike_rental_11[bike_rental_11['season']==4]
winter_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 265      266  2011-09-23       4   0     9        0        5           1
# 266      267  2011-09-24       4   0     9        0        6           0
# 267      268  2011-09-25       4   0     9        0        0           0
# 268      269  2011-09-26       4   0     9        0        1           1
# 269      270  2011-09-27       4   0     9        0        2           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 349      350  2011-12-16       4   0    12        0        5           1
# 350      351  2011-12-17       4   0    12        0        6           0
# 351      352  2011-12-18       4   0    12        0        0           0
# 352      353  2011-12-19       4   0    12        0        1           1
# 353      354  2011-12-20       4   0    12        0        2           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#Total number of rental for winter in the year 2011
winter_rents['cnt'].sum()
# Out:
# 326137

# %%
winter_rents['casual'].sum()
# Out:
# 52813

# %%
winter_rents['registered'].sum()
# Out:
# 273324

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(['Spring', 'Summer', 'Fall', 'Winter'], [150000, 347316, 419650, 326137], color = ['blue', 'red', 'green', 'yellow'])
# Out:
# <BarContainer object of 4 artists>

# %%
#rate of casual users per season
plt.bar(['Spring', 'Summer', 'Fall', 'Winter'], [21425, 77564, 95450, 52813], color = ['red', 'blue', 'yellow', 'green'])
# Out:
# <BarContainer object of 4 artists>

# %%
#rate of registered users per season
plt.bar(['Spring', 'Summer', 'Fall', 'Winter'], [128575, 269752, 324200, 273324], color = ['orange', 'blue', 'purple', 'green'])
# Out:
# <BarContainer object of 4 artists>

# %%
#Holiday/Weekends rentage
holiday_rents = bike_rental_11[bike_rental_11['workingday']==0]
holiday_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 14        15  2011-01-15       1   0     1        0        6           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 351      352  2011-12-18       4   0    12        0        0           0
# 357      358  2011-12-24       1   0    12        0        6           0
# 358      359  2011-12-25       1   0    12        0        0           0
# 359      360  2011-12-26       1   0    12        1        1           0
# 364      365  2011-12-31       1   0    12        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
holiday_rents['cnt'].sum()
# Out:
# 386839

# %%
#Weekdays rentage
weekday_rents = bike_rental_11[bike_rental_11['workingday']==1]
weekday_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 356      357  2011-12-23       1   0    12        0        5           1
# 360      361  2011-12-27       1   0    12        0        2           1
# 361      362  2011-12-28       1   0    12        0        3           1
# 362      363  2011-12-29       1   0    12        0        4           1
# 363      364  2011-12-30       1   0    12        0        5           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
weekday_rents['cnt'].sum()
# Out:
# 856264

# %%
plt.bar(['Holiday', 'Weekdays'], [386839, 856264], color = ['chocolate', 'magenta'])
# Out:
# <BarContainer object of 2 artists>

# %%
bike_rental_11['registered'].sum()
# Out:
# 995851

# %%
bike_rental_11['casual'].sum()
# Out:
# 247252

# %%
plt.bar(['registered', 'casual'], [995851, 247252], color = ['chocolate', 'magenta'])
plt.title("Rate of Registered users vs Causal users")
# Out:
# Text(0.5, 1.0, 'Rate of Registered users vs Causal users')

# %%
import seaborn as sns
